# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset.csv")
num_cols = df._get_numeric_data()

# %%
for col in num_cols.columns:
    if df_numeric[col].isnull().sum() > 0:
        df_numeric[str(col) + '_media'] = df_numeric[col].fillna(df_numeric[col].mean()) 
        df_numeric[str(col) + '_mediana'] = df_numeric[col].fillna(df_numeric[col].median())
print(df_numeric)

#deletar colunas que tinham NaN
df_numeric = df_numeric.dropna(axis="columns")

# %%
cols = df.columns
num_cols = df._get_numeric_data().columns
cat_cols = list(set(cols) - set(num_cols))

# %%
df_cat = df[cat_cols]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_catle = df_cat.apply(LabelEncoder().fit_transform)

# %%
df_cat_num = pd.merge(df_catle,df_numeric,left_index=True,right_index=True)
df_cat_num
# Out:
#         Link  Hora  Data  Localidade  Anuncio      Preco  Quartos   Area  \
# 0       8202   791    18          41     5004   470000.0      5.0  300.0
# 1       1621   789    18          27     3110   160000.0      3.0    NaN
# 2      13034   786    18          15    11267   285010.0      3.0   65.0
# 3      15555   786    18          15    11275   285038.0      3.0   65.0
# 4      12364   786    18          27       43   310011.0      3.0   74.0
# ...      ...   ...   ...         ...      ...        ...      ...    ...
# 18230   1765   468     6          20     3314   165000.0      3.0    NaN
# 18231  13744   440     6           6     8342   299522.0      2.0    NaN
# 18232   4532   433     6           3     2409   170000.0      3.0   67.0
# 18233   7277   359     6           6     4511  1200000.0      4.0    NaN
# 18234  11655  1038     2          12     7304   273610.0      NaN    0.0
#
#        TaxaCond  VagasGaragem  Quartos_media  Quartos_mediana  Area_media  \
# ...

# %%
#NORMALIZAR
#PCA
